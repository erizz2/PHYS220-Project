# %% [markdown]
# <a href="https://colab.research.google.com/github/erizz2/PHYS220-Project/blob/main/code/PHYS220proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import useful libraries
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy.integrate import quad

# functions
def calculateBn(init, n, x, L):
    return (2 / L) * scipy.integrate.quad(init(x) * np.sin((n * np.pi * x) / L), 0, L)

def u(x, t, N):
  for n in range(1, N+1):

  return sin(n * np.pi * x / L) * exp(-a(n * np.pi / L)**2 * t)

# main
if __name__ == "__main__":
    print(calculateBn())
# Out:
# hello
